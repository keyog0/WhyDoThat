# %%
import requests

# %%
r = requests.get('https://programmers.co.kr/job?_=1610273215839&job_position%5Bdummy%5D=0&order=recent&page=2')

# %%
r.text
# Out:
# iv>\n  <div class="item-body">\n    <h5 class="position-title">\n      <a href="/job_positions/4083">백엔드 개발자 (Python Django, DRF)</a>\n    </h5>\n    <h6 class="company-name">피큐레잇</h6>\n    <ul class="company-info">\n      <li class="experience">\n        <svg class=""><use xlink:href="/assets/svg-defs-4ac1fbe5512906aafb7ebe941f35ffa814b7338e8cc6e764ebf293f001709f4f.svg#ic-laptop-14"/></svg>\n        2 ~ 8년  경력\n      </li>\n        <li class="location">\n          <svg class=""><use xlink:href="/assets/svg-defs-4ac1fbe5512906aafb7ebe941f35ffa814b7338e8cc6e764ebf293f001709f4f.svg#ic-location-14"/></svg>\n          서울 마포구\n        </li>\n\n      <li class="bonus">\n        <svg class=""><use xlink:href="/assets/svg-defs-4ac1fbe5512906aafb7ebe941f35ffa814b7338e8cc6e764ebf293f001709f4f.svg#ic-money-14"/></svg>\n        사이닝 보너스 500,000\n      </li>\n    </ul>\n    <ul class="list-position-tags">\n        <li class="stack-item">서버/백엔드</li>\n        <li class="stack-item">웹 풀스택</li>\n     
# ...
